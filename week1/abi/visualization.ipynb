# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('../dataset/comtrade.csv')

# %%
df['Trade Value (US$)'].hist(figsize=(10,7));

# %%
#df.plot(kind='line', subplots=True, layout=(3,3), figsize=(10,7))
df['Trade Value (US$)'].plot(kind='box', figsize=(10,7))

# %%
corr = df.corr()
sns.heatmap(corr);

# %%
plt.figure(figsize=(10,12))
sns.barplot('Trade Value (US$)','Reporter', data=df)
